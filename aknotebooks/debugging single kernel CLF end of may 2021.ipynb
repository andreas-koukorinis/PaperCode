# %%
import sys
sys.path.append('/home/ak/Documents/Research/PaperCode/singlekernelclf/')
from fileutils import DataLoader as DataLoader
from fileutils import paths
from fileutils import new_feature_utils as nfu
from fileutils.new_feature_utils import CreateMarketFeatures
from clfutils import FitModels
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import precision_recall_fscore_support
import pandas as pd
import numpy as np
import datetime as dt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import roc_auc_score, accuracy_score, f1_score, recall_score, precision_score, hamming_loss
import os
import multiprocessing
import psutil
import pickle
from collections import defaultdict
import itertools

# %%
def open_pickle_filepath(pickle_file):
    pickle_to_file = pickle.load(open(pickle_file, "rb"), encoding='latin1')

    return pickle_to_file


def forwardDates(list_of_keys, current_date):
    """
    return all the forward looking dates for each idxKey we use for training

    :param list_of_keys: dates i have model dates for out of sample
    :param current_date: current model date
    :return: forward dates for applying the fitted model
    """
    lookAheadKeys = sorted(i for i in list_of_keys if i > current_date)
    return lookAheadKeys


def evaluate_predictions(y_true, y_preds):
    """
    Performs evaluation comparison on y_true labels vs. y_pred labels
    on a classification.
    """
    accuracy = accuracy_score(y_true, y_preds)
    precision = precision_score(y_true, y_preds, average='weighted')
    precision_macro = precision_score(y_true, y_preds, average='macro')
    precision_micro = precision_score(y_true, y_preds, average='micro')
    recall = recall_score(y_true, y_preds, average='weighted')
    f1_weighted = f1_score(y_true, y_preds, average='weighted')
    f1_macro = f1_score(y_true, y_preds, average='macro')
    f1_micro = f1_score(y_true, y_preds, average='micro')
    hamming_loss_value = hamming_loss(y_true, y_preds)

    metric_dict = {"accuracy": round(accuracy, 2),
                   "precision": round(precision, 2),
                   "recall": round(recall, 2),
                   "f1- weighted": round(f1_weighted, 2),
                   "f1- micro": round(f1_micro, 2),
                   "f1- macro": round(f1_macro, 2),
                   "Hamming Loss": round(hamming_loss_value, 2)}
    print(f"Acc: {accuracy * 100:.2f}%")
    print(f"Precision: {precision:.2f}")
    print(f"Recall: {recall:.2f}")
    print(f"F1 score weighted: {f1_weighted:.2f}")
    print(f"F1 score macro: {f1_macro:.2f}")
    print(f"F1 score micro: {f1_micro:.2f}")
    print(f"Hamming Loss Value: {hamming_loss_value:.2f}")

    return metric_dict

# %%
targetMainPath = '/media/ak/DataOnly/'
symbolFeaturesDirectories = os.path.join(targetMainPath, 'SymbolFeatureDirectories')

# %%
os.path.join(symbolFeaturesDirectories,os.listdir(symbolFeaturesDirectories)[2])
# Out:
# '/media/ak/DataOnly/SymbolFeatureDirectories/NG.L'

# %%
# alternate_labels_nos = [1, 2, 3, 4, 5, 6, 7]  # we have 7 alternative data types
mainPath = paths('main')
label_idx = 0  # to be serialised


fittedModelsPath = os.path.join(mainPath, "ExperimentCommonLocs/FittedModels")
oosPredictionsPath = os.path.join(mainPath, "ExperimentCommonLocs/OOSPredictions")

symbols = sorted(os.listdir(paths('symbols_features')))
print(symbols) # all symbols
# Out:
# ['AAL.L', 'APF.L', 'AV.L', 'AZN.L', 'BARC.L', 'BATS.L', 'BLT.L', 'CCL.L', 'CEY.L', 'CNA.L', 'CPG.L', 'DGE.L', 'HSBA.L', 'IOG.L', 'ITV.L', 'KGF.L', 'LAND.L', 'LGEN.L', 'LLOY.L', 'MAB.L', 'MKS.L', 'NG.L', 'PRU.L', 'PSON.L', 'RB.L', 'RBS.L', 'RDSa.L', 'RDSb.L', 'REL.L', 'RR.L', 'RSA.L', 'RTO.L', 'SDR.L', 'SGE.L', 'SHP.L', 'SMIN.L', 'SPT.L', 'STAN.L', 'TSCO.L', 'ULVR.L', 'UU.L', 'VOD.L', 'WPP.L']

# %%
#/media/ak/DataOnly/ExperimentCommonLocs/FittedModels
np.unique([f.split("_")[0] for f in os.listdir(fittedModelsPath)])
# Out:
# array(['AAL.L', 'AZN.L', 'BATS.L', 'CCL.L', 'LAND.L', 'LLOY.L', 'MKS.L',
#        'PRU.L', 'RB.L'], dtype='<U6')

# %%
os.listdir(fittedModelsPath)
# Out:
# ['LLOY.L_model_fit_date_20170724_6_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170711_4_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20180411_6_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170918_5_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20180221_5_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170913_7_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170804_5_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170123_7_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170809_2_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170821_2_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20180411_3_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170119_5_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170706_3_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170124_4_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170803_4_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170130_2_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170721_6_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170818_5_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170705_2_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170705_4_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170720_4_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170126_3_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170801_3_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170919_6_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20180214_5_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170124_3_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170803_3_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170814_6_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170712_2_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170817_4_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170724_7_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170823_6_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170131_6_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170823_5_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170907_7_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170119_2_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170919_5_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170126_4_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20180420_5_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170728_5_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170922_7_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20180404_5_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170822_7_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170915_6_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170817_6_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170123_6_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170727_7_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20180410_4_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170920_7_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170804_7_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170906_7_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170704_3_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170914_7_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170817_3_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170126_5_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170811_5_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170907_6_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170801_4_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170919_5_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20180216_6_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20180222_6_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170825_7_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20171023_6_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170804_5_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170906_7_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170127_2_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170822_7_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20180212_7_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170821_6_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170725_2_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170118_7_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170725_6_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170125_7_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20180416_5_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170808_5_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170120_5_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170829_2_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170921_6_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20171003_7_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170123_5_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20171017_5_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20180405_6_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170904_5_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170126_7_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20180209_7_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170817_7_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170802_5_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170713_4_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170125_3_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20171011_5_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20171004_7_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20180420_4_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20171016_7_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20171011_6_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170911_6_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170904_5_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20171020_5_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20171027_5_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20180216_7_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170821_7_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170811_6_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20180212_3_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170913_5_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20171228_3_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20180417_6_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170717_3_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170802_3_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170929_5_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170707_3_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170720_5_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170728_5_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170719_4_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170817_6_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20180420_5_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170130_7_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20171030_6_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170123_3_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170913_5_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20180220_5_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20180219_5_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170802_7_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20180226_4_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170815_7_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170711_2_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170818_7_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170809_3_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170707_7_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20180411_5_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20180205_4_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20171206_3_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170929_5_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170724_2_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170825_5_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170922_5_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170123_7_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20180201_4_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170912_5_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20180206_6_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20180416_4_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170821_7_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20171005_6_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20171013_6_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170908_6_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20180202_5_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170823_4_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170821_6_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170815_6_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20180409_5_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20171023_5_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170810_5_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170727_4_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170725_3_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20180419_4_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170119_4_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20171012_6_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170728_4_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170816_6_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20180228_5_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170718_6_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20180208_6_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170829_6_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170907_5_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170731_5_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170124_5_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170908_6_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170914_5_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170125_5_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170818_5_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20171012_7_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170818_2_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170726_4_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20171025_7_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170911_5_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170816_7_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170119_3_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170804_3_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20180219_4_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170808_6_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20171013_7_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170720_3_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170727_5_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20180206_5_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170814_3_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170808_7_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20180227_5_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20180404_3_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20180403_6_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170124_7_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170705_6_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170808_7_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20171012_5_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20180413_3_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170803_7_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170119_6_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20180417_4_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170914_5_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20180209_4_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170831_7_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20171026_6_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20171221_3_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20180419_5_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20171016_6_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170707_2_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170120_7_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20180412_5_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20171009_5_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20180416_3_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20180216_5_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20180412_6_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170118_4_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170822_4_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20180227_6_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170825_5_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170718_4_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170731_5_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170921_7_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170802_6_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170712_6_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170802_3_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170814_7_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20171011_6_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20180418_7_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170119_6_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20180404_4_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170801_2_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20180413_6_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20180219_7_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170831_5_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20180413_4_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170714_2_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170824_5_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170117_6_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20180227_7_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20171031_6_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20180418_3_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20180205_5_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170131_5_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170904_6_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170818_6_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20180405_6_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170824_6_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170807_6_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170727_2_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20171018_6_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20171011_7_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170919_6_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170818_3_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170705_5_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170711_7_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170123_6_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20171002_6_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20171027_6_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20180201_5_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170717_7_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20171004_6_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20180403_3_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170901_6_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20171004_6_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170724_3_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20180419_6_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170811_7_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170714_4_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170127_7_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20180207_6_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20180202_3_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170906_6_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20180226_3_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170707_5_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170118_6_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170719_3_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20180406_6_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20180403_5_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170830_5_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170717_5_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170131_7_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20171204_3_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20171013_5_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170131_3_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20171004_5_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20171005_5_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20180403_7_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170712_3_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170131_4_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170915_5_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170123_2_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170801_3_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170915_7_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20180223_4_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170718_3_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170811_2_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20180215_7_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170803_7_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170829_5_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170717_5_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170815_4_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170718_7_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20180406_3_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20171229_3_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20180221_7_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20180202_4_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170921_5_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20180411_6_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170816_3_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170727_6_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20180207_4_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170915_6_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20180212_5_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170911_7_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170808_2_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20180215_5_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170929_7_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170118_3_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20171201_3_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170118_7_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170811_4_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170829_3_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170712_7_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20180227_4_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20180406_7_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170130_6_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20180228_5_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170201_6_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170721_3_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170809_5_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170814_5_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170811_6_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170908_5_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170831_3_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170720_2_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20180213_6_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170717_2_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170124_6_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20180216_5_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20171010_5_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170803_5_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20171010_6_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170127_5_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20180226_5_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170918_7_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170117_4_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20180209_6_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170825_2_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170704_7_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20180417_6_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170131_6_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20171027_7_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170714_3_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170717_6_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20180412_3_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170830_6_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170927_7_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170904_7_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20180221_4_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170927_6_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170125_6_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170728_2_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170815_3_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170914_6_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170131_2_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20180215_4_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20180411_7_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170907_6_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170120_4_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170811_5_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170724_3_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170705_3_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20180221_6_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170901_7_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170821_3_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170706_4_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170818_4_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20180404_6_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170825_6_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20171005_7_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170816_5_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170817_7_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170811_3_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20180222_4_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20171019_6_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170908_7_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170117_2_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170119_3_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170816_3_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170905_7_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170822_3_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20180222_5_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170127_6_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170706_6_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170124_7_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20180416_6_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170913_6_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170824_6_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170925_6_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20180405_3_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20180213_4_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170719_5_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20180419_7_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170905_6_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170824_7_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20171031_7_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170126_2_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20180223_6_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170908_7_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170926_7_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170821_5_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170830_7_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20180213_3_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170830_3_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170926_6_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170704_6_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170125_4_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20171214_3_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170818_6_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170807_7_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20180214_7_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170830_7_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170831_4_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170808_5_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20180418_5_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170918_5_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170127_4_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20171024_6_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170804_4_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20180410_6_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170911_7_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170726_3_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170727_5_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170703_7_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170809_3_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170705_7_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170808_4_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170831_3_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170710_4_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170712_5_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170811_7_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20171024_7_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20180205_6_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170119_7_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170728_6_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20180222_7_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20180419_5_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170718_5_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170814_4_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170825_3_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20171018_7_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170920_6_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170118_6_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20180202_6_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20180216_3_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20171023_7_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170713_5_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20180228_6_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20180420_7_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170726_7_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20180206_4_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170905_5_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20180201_3_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170925_7_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20171017_7_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170714_5_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20180228_7_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20171005_6_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20180222_3_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20171002_7_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20171212_3_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170728_7_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170929_6_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170821_3_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170130_6_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20171018_5_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170807_5_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170920_5_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20171020_6_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170719_6_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170815_6_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170125_2_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170919_7_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170914_6_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20171010_7_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20180412_4_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170801_7_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170825_4_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170825_3_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170721_3_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170706_3_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20180201_7_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20180208_4_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170801_6_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170712_3_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20180413_7_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170824_5_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170125_7_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20180207_5_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170724_4_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170713_7_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170911_6_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20180406_5_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170808_6_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20180410_7_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170918_6_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170809_7_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170711_3_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20180409_6_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170809_6_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170822_6_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170823_2_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170726_6_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170824_3_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170831_7_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170808_3_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20171017_6_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170809_5_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20180406_6_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170907_7_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20180403_4_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20180219_3_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20180413_6_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170802_7_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170710_5_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170807_3_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170824_2_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170905_6_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20171009_6_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170706_7_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170829_4_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170822_6_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170201_6_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20171227_3_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170704_4_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20180208_5_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170922_6_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170918_6_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170823_5_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170829_3_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20171020_6_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170810_5_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170925_5_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20180215_3_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170711_5_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170906_6_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20180406_5_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170901_5_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20180228_4_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20180213_5_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20171024_6_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170906_5_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170117_6_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170703_6_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20180223_5_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170807_3_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170125_6_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170801_6_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170925_6_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20171030_6_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170707_5_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170927_6_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170118_2_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170814_3_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170705_5_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170126_3_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170714_5_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170719_3_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20171003_6_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170829_7_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170807_5_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170822_3_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170814_6_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20180209_3_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20180214_5_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170831_5_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20180406_4_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170704_3_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170728_3_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170704_5_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170126_6_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170830_5_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20180215_6_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20180201_6_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170130_3_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20171222_3_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20180215_5_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20180223_5_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170117_7_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170818_7_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170721_2_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20180411_5_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170117_3_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170713_3_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20171009_7_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20180212_4_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20180409_6_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20171019_7_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170830_6_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20171009_6_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170703_2_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20180418_6_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170921_5_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170124_6_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170301_2_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170809_7_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20180209_5_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170714_6_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170919_7_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170130_7_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170718_5_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170822_5_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20180403_5_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170725_4_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170810_6_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170922_5_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170810_7_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170823_7_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170120_3_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20171024_5_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20171205_3_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170825_6_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20180412_6_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170816_6_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170810_6_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170728_3_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20171006_6_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170824_4_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170810_3_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170712_5_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170814_7_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20180417_3_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170703_4_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20180221_3_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170825_7_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170823_7_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170726_2_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20180206_5_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170801_5_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170927_5_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170713_3_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170711_5_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170803_3_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20171018_6_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20180405_5_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170926_6_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170727_3_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170127_3_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20171026_5_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170821_5_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170814_2_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20180411_4_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170719_7_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170816_7_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170810_3_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20180221_5_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20171006_5_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170803_2_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170815_5_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20171030_7_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170710_3_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20180214_6_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170913_6_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170804_3_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20171006_7_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20180205_3_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170711_3_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170731_7_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170712_4_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170727_3_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170725_5_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20171213_3_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20180220_6_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170711_6_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170918_7_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20180206_7_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170721_5_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170927_7_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20180405_7_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170821_4_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170807_2_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20171031_5_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20171218_3_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170721_5_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20180207_3_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170801_7_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170802_4_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20180416_5_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20171219_3_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170703_3_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20180409_7_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20180205_5_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170726_5_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170817_5_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20180226_7_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170720_3_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170123_4_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170120_6_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170818_3_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170830_4_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170807_4_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20180410_5_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170811_3_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170726_3_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170720_5_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20180405_5_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170713_2_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170301_6_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170118_5_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170823_6_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20171025_5_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20180207_7_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20180213_7_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170913_7_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170816_5_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170926_5_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170703_3_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170904_6_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170706_5_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170717_3_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170717_4_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20171027_6_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170914_7_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170714_3_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20180416_7_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20180413_5_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170926_5_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20171006_6_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20180417_5_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170912_6_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20171019_6_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20180409_4_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170803_5_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170804_6_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170125_3_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20171013_6_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170120_7_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20180208_7_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20180409_5_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20180410_3_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170912_5_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170120_3_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170829_7_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170915_5_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20180417_7_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170705_3_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170120_6_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170707_4_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170829_5_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20171207_3_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170905_5_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20180219_5_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170802_2_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170804_6_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20180418_5_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170830_2_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170816_4_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170925_5_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20171211_3_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20180216_4_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170126_7_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170929_6_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20180223_3_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20180228_3_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20180227_5_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170721_7_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170912_6_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170706_5_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170719_5_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170807_6_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170710_2_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20171020_7_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170706_2_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20171220_3_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170829_6_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20180212_6_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170831_6_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170731_6_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170926_7_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170131_7_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20180208_5_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170707_6_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20180404_6_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170911_5_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170816_2_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20180418_4_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20180226_6_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170815_3_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170823_3_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20180223_7_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170724_5_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170703_5_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170815_2_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170710_3_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170118_3_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20171012_6_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170822_2_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20171030_5_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170921_7_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170810_2_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170808_3_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170928_6_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170803_6_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20171208_3_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170731_3_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170823_3_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20180219_6_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170718_2_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170731_2_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170117_3_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20180419_3_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20180214_4_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170928_7_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170713_5_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20180420_3_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170130_4_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170725_5_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20180220_7_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170710_5_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20171016_5_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20180404_7_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20180206_3_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170801_5_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20180220_4_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170705_7_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170809_4_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170704_7_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20171002_5_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20171019_5_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170831_6_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170802_6_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20180410_6_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170131_3_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170804_7_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20180410_5_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170810_4_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20171023_6_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170713_6_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20180412_5_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20180205_7_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170817_2_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20180220_3_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170831_2_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170904_7_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170905_7_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170120_2_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170912_7_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170809_6_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170928_7_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170920_5_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170928_5_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170127_7_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170912_7_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20180214_3_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170704_5_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170124_3_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170901_5_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170706_7_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20171017_6_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170922_7_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170718_3_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20171026_7_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170719_2_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170127_6_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20180220_5_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170907_5_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20180403_6_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170130_3_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20180416_6_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170925_7_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170815_5_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20180413_5_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170803_6_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170927_5_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170130_5_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170928_6_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20180207_5_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20180202_7_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170123_3_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20180405_4_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170817_5_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170901_7_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20171003_6_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170804_2_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20171025_6_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20180212_5_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20171003_5_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170922_6_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20180409_3_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170810_7_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170710_7_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170126_6_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20171031_6_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20171025_6_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20180201_5_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170824_3_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20171215_3_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170807_7_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170921_6_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170824_7_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170124_2_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170714_7_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20180227_3_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170720_7_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170906_5_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170830_3_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170929_7_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170725_3_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170301_3_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170720_6_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170731_3_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170704_2_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170928_5_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170815_7_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170117_7_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20180213_5_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20171026_6_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170726_5_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20180226_5_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170915_7_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20170901_6_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20171002_6_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170725_7_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170119_7_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170127_3_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20180208_3_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20180222_5_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20171010_6_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20180404_5_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170908_5_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20180417_5_SingleKernelSVC.pkl',
#  'AAL.L_model_fit_date_20170817_3_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170920_6_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170721_4_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170724_5_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20180420_6_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170814_5_SingleKernelSVC.pkl',
#  'AZN.L_model_fit_date_20170920_7_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20180412_7_SingleKernelSVC.pkl',
#  'RB.L_model_fit_date_20170707_3_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170301_4_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20180202_5_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20170802_5_SingleKernelSVC.pkl',
#  'MKS.L_model_fit_date_20180209_5_SingleKernelSVC.pkl',
#  'CCL.L_model_fit_date_20170822_5_SingleKernelSVC.pkl',
#  'PRU.L_model_fit_date_20170731_4_SingleKernelSVC.pkl',
#  'BATS.L_model_fit_date_20171016_6_SingleKernelSVC.pkl',
#  'LAND.L_model_fit_date_20170703_7_SingleKernelSVC.pkl',
#  'LLOY.L_model_fit_date_20170710_6_SingleKernelSVC.pkl']

# %%
symbol_idx = 7
symbol = symbols[symbol_idx]  # to be serialised so read all the symbols
print(symbol)
# Out:
# CCL.L

# %%
alternate_labels_nos = [ 1, 2, 3, 4, 5, 6, 7]  # we have 7 alternative data types
mainPath = paths('main')
symbolData = DataLoader(mainPath, symbol) # initiate a path where all the data should be
pickled_models = [f for f in os.listdir(fittedModelsPath) if str(symbol) in f]  # list of all the pickled models
print(pickled_models)

# %%
best_svc[str(symbol)][model_date]['SVC'].cv_results_

# %%
  print('******* Finished and now saving -*-*-*-')
    
                        pickle_out_filename = os.path.join(oosPredictionsPath, "_".join(
                            (symbol, str("Label_" )+ str(alternate_labels_nos[label_idx]), forwardDateKey, 'OOS_results_dict.pkl')))
                        pickle_out = open(pickle_out_filename, 'wb')
                        pickle.dump(oos_svc_predictions, pickle_out)
                        pickle_out.close()
                        print('saved', pickle_out_filename)

# %%
len(np.unique(error_dates)) # actual unique dates
str("Label_" )+ str(alternate_labels_nos[label_idx])

# %%
labels_dates =list(labels_paths.keys())
len(labels_dates)

# %%
len(list(set(forwardDatesList).intersection(labels_dates)))

# %%
oosPredictionsPath

# %%
    #                         # create features - first HMM and second some Market Features!
    #
    #                         hmm_features = nfu.hmm_features_df(open_pickle_filepath(features_paths[forwardDateKey]))
    #
    #                         if hmm_features.isnull().values.all():
    #                             print('Problem: your HMM features did not compute properly')
    #                         else:
    #
    #                             market_features_df = CreateMarketFeatures(
    #                                 CreateMarketFeatures(
    #                                     CreateMarketFeatures(df=CreateMarketFeatures(df=labels).ma_spread_duration())
    #                                         .ma_spread()).chaikin_mf()).obv_calc()  # market features dataframe
    #
    #                             df_concat = pd.DataFrame(
    #                                 pd.concat([hmm_features, market_features_df], axis=1, sort='False').dropna())
    #
    #                             df = df_concat[df_concat[label_name].notna()]
    #                             df_final = df.drop(
    #                                 columns=['TradedPrice', 'Duration', 'TradedTime', 'ReturnTradedPrice',
    #                                          'Volume', label_name])
    #
    #                             y_test = df[df.columns[df.columns.str.contains(pat='label')]].iloc[:, 0]

# %%
for best_svc_key_date in best_svc_key_dates:
            #     #
            #     #     # all the various combinations of HMM dates,
            #     #     # features models.
            #     #
            #     #     # all the labels dates that are after the key date that this model was fitted
            #
            #
            #
            #         # all the various paths
            #
            #         features_paths = symbolData.hmm_model_date_feature_list_filepaths(hmm_date)[1]
            #
            #         # for each forward date
            #
            #         for forwardDateKey in forwardDatesList:
            #
            #             if model_date < forwardDateKey:  # simple check that your model date is not after your forward date!
            #                 oos_svc_predictions = defaultdict(dict)
    #
    #                         # get your labels
    #
    #                         labels = pd.read_csv(labels_paths[forwardDateKey])
    #                         label_name = str(labels.columns[labels.columns.str.contains(pat='label')].values[0])
    #
    #                         # create features - first HMM and second some Market Features!
    #
    #                         hmm_features = nfu.hmm_features_df(open_pickle_filepath(features_paths[forwardDateKey]))
    #
    #                         if hmm_features.isnull().values.all():
    #                             print('Problem: your HMM features did not compute properly')
    #                         else:
    #
    #                             market_features_df = CreateMarketFeatures(
    #                                 CreateMarketFeatures(
    #                                     CreateMarketFeatures(df=CreateMarketFeatures(df=labels).ma_spread_duration())
    #                                         .ma_spread()).chaikin_mf()).obv_calc()  # market features dataframe
    #
    #                             df_concat = pd.DataFrame(
    #                                 pd.concat([hmm_features, market_features_df], axis=1, sort='False').dropna())
    #
    #                             df = df_concat[df_concat[label_name].notna()]
    #                             df_final = df.drop(
    #                                 columns=['TradedPrice', 'Duration', 'TradedTime', 'ReturnTradedPrice',
    #                                          'Volume', label_name])
    #
    #                             y_test = df[df.columns[df.columns.str.contains(pat='label')]].iloc[:, 0]
    #
    #                             try:
    #
    #                                 X_test = MinMaxScaler().fit_transform(df_final)
    #
    #                                 y_pred = best_svc[str(symbol)][model_date]['SVC'].predict(X_test)
    #                                 print(evaluate_predictions(y_test, y_pred))
    #                                 # store the results
    #                                 results_predict_alias = "_".join(
    #                                     (symbol, forwardDateKey, str(alternate_labels_nos[label_idx])))
    #                                 oos_svc_predictions[results_predict_alias][forwardDateKey] = evaluate_predictions(
    #                                     y_test, y_pred)
    #
    #                             except ValueError:
    #                                 print('value error here:****************************************')
    #                                 continue
    #
    #                     else:
    #
    #                         pass
    #

# %%
best_svc['CCL.L']['20170710']

# %%
def iterdict(d):
    for k, v in d.items():
        if isinstance(v, dict):
            iterdict(v)
        else:
            print (k, ":", v)

# %%
best_svc.items()
