# %%
import os
import pandas as pd
import numpy as np

# %%
path = '/media/ak/T71/August11th2022Experiments/QuadMMDOutputFiles/'
processedDF = os.path.join(path, 'processedDataFrames')

# %%
bar_choice = 'tick'
symbol_choice = 'TY1'
allFiles = os.listdir(processedDF)
bar_choice_files = [f for f in allFiles if str(bar_choice) in f]
symbol_choice_files = [f for f in allFiles if str(symbol_choice) in f]

# %%
bar_choice_files
# Out:
# ['G_1_tick_processedAlphaResults_window__DF.pkl',
#  'TY1_tick_processedAlphaResults_window__DF.pkl',
#  'XM1_tick_processedAlphaResults_window__DF.pkl']

# %%
g_1 = pd.read_pickle(os.path.join(processedDF, bar_choice_files[0]))
xm1 = pd.read_pickle(os.path.join(processedDF, bar_choice_files[2]))

# %%
g_1
# Out:
#              Kxx       Kxy       Kyy  XZ_test_alpha  XZ_test_h0_rejected  \
# window
# 5       0.602241  0.602154  0.602815           0.05             0.944099
# 15      0.601967  0.600764  0.600550           0.05             0.944538
# 25      0.602357  0.601388  0.601660           0.05             0.950459
# 35      0.601009  0.601287  0.602802           0.05             0.927273
# 45      0.601346  0.601584  0.602446           0.05             0.919101
# 55      0.603872  0.602246  0.601203           0.05             0.944304
# 65      0.604821  0.603576  0.603024           0.05             0.933333
# 75      0.604489  0.604469  0.604448           0.05             0.908475
# 85      0.606063  0.604777  0.603712           0.05             0.946939
# 95      0.602974  0.604840  0.608127           0.05             0.958974
#
#         XZ_test_list_permuted_mmd2  XZ_test_pvalue  XZ_test_test_stat  \
# window
# 5                        -0.002843        0.024964           0.254528
# ...

# %%
xm1
# Out:
#              Kxx       Kxy       Kyy  XZ_test_alpha  XZ_test_h0_rejected  \
# window
# 5       0.602241  0.602154  0.602815           0.05             0.944099
# 15      0.601967  0.600764  0.600550           0.05             0.944538
# 25      0.602357  0.601388  0.601660           0.05             0.950459
# 35      0.601009  0.601287  0.602802           0.05             0.927273
# 45      0.601346  0.601584  0.602446           0.05             0.919101
# 55      0.603872  0.602246  0.601203           0.05             0.944304
# 65      0.604821  0.603576  0.603024           0.05             0.933333
# 75      0.604489  0.604469  0.604448           0.05             0.908475
# 85      0.606063  0.604777  0.603712           0.05             0.946939
# 95      0.602974  0.604840  0.608127           0.05             0.958974
#
#         XZ_test_list_permuted_mmd2  XZ_test_pvalue  XZ_test_test_stat  \
# window
# 5                        -0.002843        0.024964           0.254528
# ...
