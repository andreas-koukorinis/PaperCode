# %%
import json
import os
import pandas as pd

# %%
def create_parameter_sets(base_input_folder, base_output_folder, symbols, event_clock_destinations, threshold_values,
                          columns_to_resample, exclude_median_columns):
    """
    Creates parameter sets for event clock resampling.

    Args:
        base_input_folder (str): Base input folder containing subfolders for each symbol.
        base_output_folder (str): Base output folder.
        symbols (List[str]): List of symbols.
        event_clock_destinations (Dict[str, str]): Dictionary mapping event clocks to their destinations.
        threshold_values (List[int]): List of threshold values for each event clock.
        columns_to_resample (List[str]): Columns to be resampled.
        exclude_median_columns (List[str]): Columns to exclude from median calculation.

    Returns:
        List[Dict[str, str]]: List of parameter sets.

    """
    parameter_sets = []

    for symbol in symbols:
        input_folder = os.path.join(base_input_folder, symbol)
        output_folder = os.path.join(base_output_folder, symbol)

        # Collect all files in the input folder
        input_files = [os.path.join(input_folder, file) for file in os.listdir(input_folder) if file.endswith('.pkl')]

        for event_clock, event_clock_destination, threshold_value in zip(event_clock_destinations.keys(),
                                                                         event_clock_destinations.values(),
                                                                         threshold_values):
            for input_file in input_files:
                params = {
                    'input_file': input_file,
                    'output_folder': os.path.join(output_folder, event_clock_destination),
                    'event_clock_column': event_clock,
                    'event_clock_threshold': threshold_value,
                    'columns_to_resample': columns_to_resample,
                    'exclude_median_columns': exclude_median_columns,
                }
                parameter_sets.append(params)

    return parameter_sets


# Define the parameters
base_input_folder = '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB'
base_output_folder = '/media/ak/Data/InterestRateFuturesData/EventClocksFiles'
symbols = [ 'UST2y']
event_clock_destinations = {
    'NoOfTrades': 'tick',
    'TradedVolume': 'volume',
    'CCYTradedVolume': 'dollar',
    # Add more event clocks and their destinations if needed
}
threshold_values = [3, 10, 10000]  # Specify threshold values for each event clock
columns_to_resample = ['time','BestBid', 'BestAsk', 'MicroPrice', 'arrival_rate', 'MeanRelativeTickVolume', 'OrderImbalance']
exclude_median_columns = []

# Create the parameter sets
parameter_sets = create_parameter_sets(base_input_folder, base_output_folder, symbols, event_clock_destinations,
                                       threshold_values, columns_to_resample, exclude_median_columns)
print(parameter_sets)
# Save parameter sets to a JSON file
config_filepath = '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/configmany.json'
with open(config_filepath, 'w') as f:
    json.dump(parameter_sets, f, indent=4)
# Out:
# [{'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180413.pkl', 'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick', 'event_clock_column': 'NoOfTrades', 'event_clock_threshold': 3, 'columns_to_resample': ['time', 'BestBid', 'BestAsk', 'MicroPrice', 'arrival_rate', 'MeanRelativeTickVolume', 'OrderImbalance'], 'exclude_median_columns': []}, {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180416.pkl', 'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick', 'event_clock_column': 'NoOfTrades', 'event_clock_threshold': 3, 'columns_to_resample': ['time', 'BestBid', 'BestAsk', 'MicroPrice', 'arrival_rate', 'MeanRelativeTickVolume', 'OrderImbalance'], 'exclude_median_columns': []}, {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180417.pkl', 'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick', 'event_clock_column': 'NoOfTrades', 'event_clock_threshold': 3, 'columns_to_resample': ['time', 'BestBid', 'BestAsk', 'MicroPrice', 'arrival_rate', 'MeanRelativeTickVolume', 'OrderImbalance'], 'exclude_median_columns': []}, {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180418.pkl', 'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick', 'event_clock_column': 'NoOfTrades', 'event_clock_threshold': 3, 'columns_to_resample': ['time', 'BestBid', 'BestAsk', 'MicroPrice', 'arrival_rate', 'MeanRelativeTickVolume', 'OrderImbalance'], 'exclude_median_columns': []}, {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180419.pkl', 'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick', 'event_clock_column': 'NoOfTrades', 'event_clock_threshold': 3, 'columns_to_resample': ['time', 'BestBid', 'BestAsk', 'MicroPrice', 'arrival_rate', 'MeanRelativeTickVolume', 'OrderImbalance'], 'exclude_median_columns': []}, {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180420.pkl', 'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick', 'event_clock_column': 'NoOfTrades', 'event_clock_threshold': 3, 'columns_to_resample': ['time', 'BestBid', 'BestAsk', 'MicroPrice', 'arrival_rate', 'MeanRelativeTickVolume', 'OrderImbalance'], 'exclude_median_columns': []}, {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180423.pkl', 'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick', 'event_clock_column': 'NoOfTrades', 'event_clock_threshold': 3, 'columns_to_resample': ['time', 'BestBid', 'BestAsk', 'MicroPrice', 'arrival_rate', 'MeanRelativeTickVolume', 'OrderImbalance'], 'exclude_median_columns': []}, {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180424.pkl', 'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick', 'event_clock_column': 'NoOfTrades', 'event_clock_threshold': 3, 'columns_to_resample': ['time', 'BestBid', 'BestAsk', 'MicroPrice', 'arrival_rate', 'MeanRelativeTickVolume', 'OrderImbalance'], 'exclude_median_columns': []}, {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180425.pkl', 'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick', 'event_clock_column': 'NoOfTrades', 'event_clock_threshold': 3, 'columns_to_resample': ['time', 'BestBid', 'BestAsk', 'MicroPrice', 'arrival_rate', 'MeanRelativeTickVolume', 'OrderImbalance'], 'exclude_median_columns': []}, {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180426.pkl', 'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick', 'event_clock_column': 'NoOfTrades', 'event_clock_threshold': 3, 'columns_to_resample': ['time', 'BestBid', 'BestAsk', 'MicroPrice', 'arrival_rate', 'MeanRelativeTickVolume', 'OrderImb ...

# %%
with open(config_filepath, 'r') as f:
    parameter_sets = json.load(f)

# %%
parameter_sets
# Out:
# [{'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180413.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180416.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180417.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180418.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180419.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180420.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180423.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180424.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180425.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180426.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180427.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180430.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180501.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180502.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180503.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180504.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180507.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180509.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180510.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180511.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180514.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180515.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180516.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180517.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180518.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180521.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180522.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180523.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180524.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180525.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180528.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180529.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180530.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180531.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180604.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180605.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180606.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180607.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180608.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180611.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180612.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180613.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180614.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180615.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180618.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180619.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180620.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180621.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180622.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180625.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180626.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180628.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180629.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180702.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180703.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180704.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180705.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180706.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180709.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180710.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180711.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180712.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180713.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180716.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180717.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180718.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180719.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180720.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180508.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180601.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180627.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180723.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180816.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180911.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180724.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180725.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180726.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180727.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180730.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180731.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180801.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180802.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180803.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180806.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180807.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180808.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180809.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180810.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180813.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180814.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180815.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180817.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180820.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180821.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180822.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180823.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180824.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180827.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180828.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180829.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180830.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180831.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180903.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180904.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180905.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180906.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180907.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180910.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180912.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180913.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180914.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/tick',
#   'event_clock_column': 'NoOfTrades',
#   'event_clock_threshold': 3,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
# ...
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180906.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/dollar',
#   'event_clock_column': 'CCYTradedVolume',
#   'event_clock_threshold': 10000,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180907.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/dollar',
#   'event_clock_column': 'CCYTradedVolume',
#   'event_clock_threshold': 10000,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180910.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/dollar',
#   'event_clock_column': 'CCYTradedVolume',
#   'event_clock_threshold': 10000,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180912.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/dollar',
#   'event_clock_column': 'CCYTradedVolume',
#   'event_clock_threshold': 10000,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180913.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/dollar',
#   'event_clock_column': 'CCYTradedVolume',
#   'event_clock_threshold': 10000,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180914.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/dollar',
#   'event_clock_column': 'CCYTradedVolume',
#   'event_clock_threshold': 10000,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180917.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/dollar',
#   'event_clock_column': 'CCYTradedVolume',
#   'event_clock_threshold': 10000,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180918.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/dollar',
#   'event_clock_column': 'CCYTradedVolume',
#   'event_clock_threshold': 10000,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180919.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/dollar',
#   'event_clock_column': 'CCYTradedVolume',
#   'event_clock_threshold': 10000,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180920.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/dollar',
#   'event_clock_column': 'CCYTradedVolume',
#   'event_clock_threshold': 10000,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180921.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/dollar',
#   'event_clock_column': 'CCYTradedVolume',
#   'event_clock_threshold': 10000,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180924.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/dollar',
#   'event_clock_column': 'CCYTradedVolume',
#   'event_clock_threshold': 10000,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180925.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/dollar',
#   'event_clock_column': 'CCYTradedVolume',
#   'event_clock_threshold': 10000,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180926.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/dollar',
#   'event_clock_column': 'CCYTradedVolume',
#   'event_clock_threshold': 10000,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180927.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/dollar',
#   'event_clock_column': 'CCYTradedVolume',
#   'event_clock_threshold': 10000,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20180928.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/dollar',
#   'event_clock_column': 'CCYTradedVolume',
#   'event_clock_threshold': 10000,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20181001.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/dollar',
#   'event_clock_column': 'CCYTradedVolume',
#   'event_clock_threshold': 10000,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20181002.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/dollar',
#   'event_clock_column': 'CCYTradedVolume',
#   'event_clock_threshold': 10000,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20181003.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/dollar',
#   'event_clock_column': 'CCYTradedVolume',
#   'event_clock_threshold': 10000,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20181004.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/dollar',
#   'event_clock_column': 'CCYTradedVolume',
#   'event_clock_threshold': 10000,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20181005.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/dollar',
#   'event_clock_column': 'CCYTradedVolume',
#   'event_clock_threshold': 10000,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20181008.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/dollar',
#   'event_clock_column': 'CCYTradedVolume',
#   'event_clock_threshold': 10000,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20181009.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/dollar',
#   'event_clock_column': 'CCYTradedVolume',
#   'event_clock_threshold': 10000,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20181010.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/dollar',
#   'event_clock_column': 'CCYTradedVolume',
#   'event_clock_threshold': 10000,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20181011.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/dollar',
#   'event_clock_column': 'CCYTradedVolume',
#   'event_clock_threshold': 10000,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20181012.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/dollar',
#   'event_clock_column': 'CCYTradedVolume',
#   'event_clock_threshold': 10000,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20181015.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/dollar',
#   'event_clock_column': 'CCYTradedVolume',
#   'event_clock_threshold': 10000,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20181016.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/dollar',
#   'event_clock_column': 'CCYTradedVolume',
#   'event_clock_threshold': 10000,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20181017.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/dollar',
#   'event_clock_column': 'CCYTradedVolume',
#   'event_clock_threshold': 10000,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20181018.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/dollar',
#   'event_clock_column': 'CCYTradedVolume',
#   'event_clock_threshold': 10000,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20181019.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/dollar',
#   'event_clock_column': 'CCYTradedVolume',
#   'event_clock_threshold': 10000,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20181022.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/dollar',
#   'event_clock_column': 'CCYTradedVolume',
#   'event_clock_threshold': 10000,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20181023.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/dollar',
#   'event_clock_column': 'CCYTradedVolume',
#   'event_clock_threshold': 10000,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20181024.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/dollar',
#   'event_clock_column': 'CCYTradedVolume',
#   'event_clock_threshold': 10000,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20181025.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/dollar',
#   'event_clock_column': 'CCYTradedVolume',
#   'event_clock_threshold': 10000,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []},
#  {'input_file': '/media/ak/Data/InterestRateFuturesData/ReconstructedLOB/UST2y/20181026.pkl',
#   'output_folder': '/media/ak/Data/InterestRateFuturesData/EventClocksFiles/UST2y/dollar',
#   'event_clock_column': 'CCYTradedVolume',
#   'event_clock_threshold': 10000,
#   'columns_to_resample': ['time',
#    'BestBid',
#    'BestAsk',
#    'MicroPrice',
#    'arrival_rate',
#    'MeanRelativeTickVolume',
#    'OrderImbalance'],
#   'exclude_median_columns': []}]
