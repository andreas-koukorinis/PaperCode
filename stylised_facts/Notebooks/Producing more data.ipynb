# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os
from dateutil.parser import parse
from pandas.tseries.offsets import BDay
import pickle as pkl
import fnmatch
import pickle
import datetime as dt
from datetime import timedelta
import glob
from statsmodels.tsa.seasonal import STL
# %matplotlib inline
import fathon
from fathon import fathonUtils as fu

# %%
import stylised_facts_data_utilities.createLOB as createLOB

# %%
def open_pickle_file(path, pickle_file):
    file_loc = os.path.join(path, pickle_file)
    pickle_to_file = pickle.load(open(file_loc, "rb"))
    return pickle_to_file

# %%
extPath = '/media/ak/My Passport/ExperimentData'
barketData = '/media/ak/My Passport/Barket Data/'
#cleanBloombergDataLocation = os.path.join(dataOnlyDrive, 'CleanBloombergData')
destinationFolder = '/media/ak/My Passport/ExperimentData/ProcessedDataForExperiments'

# %%
targetDrive = barketData
bmrg_folders=[s for s in os.listdir(targetDrive ) if ('VXX') in s]
bmrg_trades=sorted([s for s in os.listdir(targetDrive ) if s.endswith('y_trades')])
bmrg_quotes=sorted([s for s in os.listdir(targetDrive ) if s.endswith('y_quotes')])
bmrg_tickers=sorted([bmrg_trades[idx].split('_t')[0] for idx,_ in enumerate(bmrg_trades)])

# %%
Folder = os.path.join(targetDrive, bmrg_folders[0])
# tradesFolder = os.path.join(targetDrive, bmrg_folders[1])

list_Files = os.listdir(Folder)

# %%
list_Files
# Out:
# ['VXX_US_Equity-20180416.csv',
#  'VXX_US_Equity-20180417.csv',
#  'VXX_US_Equity-20180418.csv',
#  'VXX_US_Equity-20180419.csv',
#  'VXX_US_Equity-20180420.csv',
#  'VXX_US_Equity-20180423.csv',
#  'VXX_US_Equity-20180424.csv',
#  'VXX_US_Equity-20180425.csv',
#  'VXX_US_Equity-20180426.csv',
#  'VXX_US_Equity-20180427.csv',
#  'VXX_US_Equity-20180430.csv',
#  'VXX_US_Equity-20180501.csv',
#  'VXX_US_Equity-20180502.csv',
#  'VXX_US_Equity-20180503.csv',
#  'VXX_US_Equity-20180504.csv',
#  'VXX_US_Equity-20180507.csv',
#  'VXX_US_Equity-20180508.csv',
#  'VXX_US_Equity-20180509.csv',
#  'VXX_US_Equity-20180510.csv',
#  'VXX_US_Equity-20180511.csv',
#  'VXX_US_Equity-20180514.csv',
#  'VXX_US_Equity-20180924.csv',
#  'VXX_US_Equity-20180925.csv',
#  'VXX_US_Equity-20180926.csv',
#  'VXX_US_Equity-20180927.csv',
#  'VXX_US_Equity-20180928.csv',
#  'VXX_US_Equity-20181001.csv',
#  'VXX_US_Equity-20181002.csv',
#  'VXX_US_Equity-20181003.csv',
#  'VXX_US_Equity-20181004.csv',
# ...

# %%
lob_dict = {}

for idx, fileName in enumerate(list_Files):
    fileLocation = os.path.join(Folder, list_Files[idx])

    raw_file = pd.read_csv(fileLocation)
    exampleLOB = createLOB.calcLOB(createLOB.formatLOB(createLOB.createLOB(raw_file)))
    lob_dict[idx] = exampleLOB
# Out:
# /home/ak/Envs/resrPyth3/lib/python3.6/site-packages/pandas/core/indexing.py:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /home/ak/Envs/resrPyth3/lib/python3.6/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /home/ak/Documents/Research/PaperCode/stylised_facts/stylised_facts_data_utilities/createLOB/__init__.py:353: RuntimeWarning: divide by zero encountered in log
#   LOB['LogTradeSize'] = np.log(LOB.TradeVolume)
# ...

# %%
lob_dict[1].columns.values
# Out:
# array(['BidQuoteId', 'BidSize', 'QuoteTime', 'type_x', 'BestBid',
#        'TradeTime', 'AskQuoteId', 'AskSize', 'time_y', 'type_y',
#        'BestAsk', 'TradeId', 'TradeVolume', 'TradedTime', 'type',
#        'TradePrice', 'TradeId', 'TimeStamp', 'milliSeconds',
#        'DollarVolume', 'MicroPrice', 'TradeSize', 'Duration',
#        'PriceChange', 'LogReturn', 'BidOffer', 'BookPressure',
#        'AskBidSizeRatio', 'MicroPricePctChange', 'FwdMPChange_1',
#        'FwdMPChange_5', 'LogTradeSize'], dtype=object)

# %%
allLOB =pd.concat(list(lob_dict.values() ), axis =0, keys = list(lob_dict.keys()))

# %%
medianVariable = allLOB.median(level=1).AskBidSizeRatio.dropna()

# %%
medianVariable.describe()
# Out:
# count    36641.000000
# mean         1.990587
# std          0.072641
# min          1.945600
# 25%          1.950550
# 50%          1.953100
# 75%          1.968900
# max          2.165700
# Name: AskBidSizeRatio, dtype: float64

# %%
a = np.asanyarray(medianVariable)

# %%
import fathon
from fathon import fathonUtils as fu
plt.style.use(os.path.join('/home/ak/.config/matplotlib','latexstyle.mplstyle'))

# %%
winSizes = fu.linRangeByStep(10, 2000)
revSeg = True
polOrd = 3

# %%
b = fu.toAggregated(a)
pydfa = fathon.DFA(a)

n, F = pydfa.computeFlucVec(winSizes, revSeg=revSeg, polOrd=polOrd)
H, H_intercept = pydfa.fitFlucVec()

# %%
# plt.plot(np.log(n), np.log(F), 'ro')
# plt.plot(np.log(n), H_intercept+H*np.log(n), '--', label='H = {:.2f}'.format(H))
# plt.xlabel('ln(n)', fontsize=14)
# plt.ylabel('ln(F(n))', fontsize=14)
# plt.title('DFA', fontsize=14)
# plt.legend(loc=0, fontsize=14)
# # title = 'DFA_BidSizeRatio'+str(bmrg_folders[0])+'_plot1'
# # plt.savefig('/home/ak/Documents/Research/Papers/figures/'+title+'.png', dpi=150)

# %%
pymfdfa = fathon.MFDFA(a)

# %%
winSizes = fu.linRangeByStep(10, 2000)
qs = np.arange(-3, 4, 0.1)
revSeg = True
polOrd = 1

# %%
n, F = pymfdfa.computeFlucVec(winSizes, qs, revSeg=revSeg, polOrd=polOrd)

# %%
list_H, list_H_intercept = pymfdfa.fitFlucVec()
# Out:
# /home/ak/Envs/resrPyth3/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.

# %%
# Just load seaborn and the chart looks better:
import seaborn as sns

plt.plot(np.log(n), np.log(F[0, :]), 'o', c='red',alpha=0.15)
plt.plot(np.log(n), list_H_intercept[0]+list_H[0]*np.log(n), '--', label='h_{:.1f} = {:.2f}'.format(qs[0], list_H[0]))
half_idx = int(len(qs)/2)
plt.plot(np.log(n), np.log(F[half_idx, :]), color='grey')
plt.plot(np.log(n), list_H_intercept[half_idx]+list_H[half_idx]*np.log(n),
         '--', label='h_{:.1f} = {:.2f}'.format(qs[half_idx], list_H[half_idx]))
plt.plot(np.log(n), np.log(F[-1, :]), 'bo',alpha=0.05)
plt.plot(np.log(n), list_H_intercept[-1]+list_H[-1]*np.log(n), '--',
         label='h_{:.1f} = {:.2f}'.format(qs[-1], list_H[-1]))
plt.xlabel('ln(n)', fontsize=14)
plt.ylabel('ln(F(n))', fontsize=14)
plt.title('MFDFA', fontsize=14)
plt.legend(loc=0, fontsize=14)
title = 'MFDFA_BidSizeRatio'+str(bmrg_folders[0])+'_plot1'
plt.savefig('/home/ak/Documents/Research/Papers/figures/'+title+'.png', dpi=150)
# Out:
# /home/ak/Envs/resrPyth3/lib/python3.6/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log
#   after removing the cwd from sys.path.

# %%
_=plt.plot(qs, list_H, 'o--', color='blue', lw=1, alpha=0.5)
_=plt.xlabel('q', fontsize=14)
_=plt.ylabel('h(q)', fontsize=14)
_=plt.title('h(q)', fontsize=14)
title = 'HQ_BidSizeRatio'+str(bmrg_folders[0])+'_plot1'
plt.savefig('/home/ak/Documents/Research/Papers/figures/'+title+'.png', dpi=150)

# %%
tau = pymfdfa.computeMassExponents()

# %%
_=plt.plot(qs, tau, 'o--', color='black',  lw=1, alpha=0.4)
_=plt.xlabel('q', fontsize=14)
_=plt.ylabel('$\\tau$(q)', fontsize=14)
_=plt.title('$\\tau$(q)', fontsize=14)
title = 'TauQ_BidSizeRatio'+str(bmrg_folders[0])+'_plot1'
plt.savefig('/home/ak/Documents/Research/Papers/figures/'+title+'.png', dpi=150)

# %%
alpha, mfSpect = pymfdfa.computeMultifractalSpectrum()

# %%
alpha = alpha[~np.isnan(alpha)]
mfSpect = mfSpect[~np.isnan(mfSpect)]

# %%
_=plt.plot(alpha, mfSpect, 'bo--')
_=plt.xlabel('$\\alpha$', fontsize=14)
_=plt.ylabel('f($\\alpha$)', fontsize=14)
_=plt.title('f($\\alpha$)', fontsize=14)
title = 'Alpha_Spectra_BidSizeRatio'+str(bmrg_folders[0])+'_plot1'
plt.savefig('/home/ak/Documents/Research/Papers/figures/'+title+'.png', dpi=150)

# %%
alpha_spectra_dict = {'alpha': alpha, 'spectra':mfSpect}

# %%
alpha_spectra_File= "".join(('alpha_spectra_dict_bidsizeratio'+str(bmrg_folders[0]), '.pkl'))
pkl.dump(alpha_spectra_dict, open("/".join((extPath, alpha_spectra_File)), "wb"))
