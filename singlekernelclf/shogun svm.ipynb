# %%
# %pylab inline
# %matplotlib inline
#To import all shogun classes
from shogun import *
import os
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import pickle as pkl
plt.style.use(os.path.join(mpl.get_configdir(), 'latexstyle.mplstyle'))
from scipy import stats
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings('ignore')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
class DataLoader(object):
    def __init__(self, path_main, ticker):
        self.main_path = path_main
        self.ticker = ticker

        self.features_labels_path = os.path.join(self.main_path, 'features_models')
        self.features_path = os.path.join(self.features_labels_path, 'features')
        # collection of per symbol non directional labels
        self.labels_path = os.path.join(self.features_labels_path, 'labels', self.ticker, 'NON_DIRECTIONAL')
        self.symbol_features_path = os.path.join(self.features_labels_path, 'features', self.ticker, 'MODEL_BASED')
        # list of all the model -oos hmm feature dates - each folder is a collection of oos feature dates
        self.hmm_dates_list = os.listdir(self.symbol_features_path)  # each folder are the OOS features from each HMM
        self.compute_date = os.listdir(os.path.join( \
            self.symbol_features_path, \
            os.listdir(self.symbol_features_path)[1]))[1].split("_")[7]

    def ticker_features(self, model_date, date):
        # need to make this a lot more flexible with number of states
        if model_date < date:
            file_name = "_".join(
                (self.ticker, '3', 'states', 'features', 'date:', date, 'now:', self.compute_date, '.pickle'))
            file_loc = os.path.join(self.symbol_features_path, str(model_date), file_name)
            with open(file_loc, 'rb') as handle:
                ticker_features = pickle.load(handle)
        else:
            print('Loading Feature Date which is in-sample. Change your Model Date')
        return ticker_features

    def ticker_labels_csv(self, date):
        file_loc = os.path.join(self.labels_path, str(date) + '.csv')
        ticker_labels = pd.read_csv(file_loc, index_col=0)
        return ticker_labels

    @staticmethod
    def open_pickle_file(path, pickle_file):
        file_loc = os.path.join(path, pickle_file)
        pickle_to_file = pickle.load(open(file_loc, "rb"))
        return pickle_to_file

    @staticmethod
    def get_date_from_file(file_, numb_):
        return os.path.splitext(file_[numb_])[0]


class MarketFeatures(object):
    # a class to be expanded that uses features for base case -market based only-indicators/features
    """"Requires:
    a dataframe that has TradedPrice And Volume columns
    symbol - A stock symbol on which to form a strategy on.
    short_window - Lookback period for short moving average.
    long_window - Lookback period for long moving average.
    """

    def __init__(self, df):
        #         self.ticker = ticker
        self.df = df

    def load_data(self):
        pass

    def ma_spread(self, short_window=5, long_window=20):
        # function that produces the MA spread, which can be used on its own or as an input for MACD
        short_rolling_px = self.df['TradedPrice'].rolling(window=short_window).mean()
        long_rolling_px = self.df['TradedPrice'].rolling(window=long_window).mean()
        px_name = "_".join(('px_indx', str(short_window), str(long_window)))
        self.df[px_name] = long_rolling_px - short_rolling_px
        return self.df

    def ma_spread_duration(self, short_window=5, long_window=20):
        # function that produces the MA spread, which can be used on its own or as an input for MACD
        short_rolling_px = self.df['Duration'].rolling(window=short_window).mean()
        long_rolling_px = self.df['Duration'].rolling(window=long_window).mean()
        dur_name = "_".join(('dur_indx', str(short_window), str(long_window)))
        self.df[dur_name] = long_rolling_px - short_rolling_px
        return self.df

    def obv_calc(self):
        # on balance volume indicator
        self.df['SignedVolume'] = self.df['Volume'] * np.sign(self.df['TradedPrice'].diff()).cumsum()
        self.df['SignedVolume'].iat[1] = 0
        self.df['OBV'] = self.df['SignedVolume']  # .cumsum()
        self.df = self.df.drop(columns=['SignedVolume'])
        return self.df

    def chaikin_mf(self, period=5):
        # Chaikin money flow indicator
        self.df["MF Multiplier"] = (self.df['TradedPrice'] - (self.df['TradedPrice'].expanding(period).min()) \
                                    - (self.df['TradedPrice'].expanding(period).max() \
                                       - self.df['TradedPrice'])) / (
                                           self.df['TradedPrice'].expanding(period).max() - self.df[ \
                                       'TradedPrice'].expanding(period).min())
        self.df["MF Volume"] = self.df['MF Multiplier'] * self.df['Volume']
        self.df['CMF_' + str(period)] = self.df['MF Volume'].sum() / self.df["Volume"].rolling(period).sum()
        self.df = self.df.drop(columns=['MF Multiplier', 'MF Volume'])
        return self.df

# %%
class DataLoader(object):
    def __init__(self, path_main, ticker):
        self.main_path = path_main
        self.ticker = ticker

        self.features_labels_path = os.path.join(self.main_path, 'features_models')
        self.features_path = os.path.join(self.features_labels_path, 'features')
        # collection of per symbol non directional labels
        self.labels_path = os.path.join(self.features_labels_path, 'labels', self.ticker, 'NON_DIRECTIONAL')
        self.symbol_features_path = os.path.join(self.features_labels_path, 'features', self.ticker, 'MODEL_BASED')
        # list of all the model -oos hmm feature dates - each folder is a collection of oos feature dates
        self.hmm_dates_list = os.listdir(self.symbol_features_path)  # each folder are the OOS features from each HMM
        self.compute_date = os.listdir(os.path.join( \
            self.symbol_features_path, \
            os.listdir(self.symbol_features_path)[1]))[1].split("_")[7]

    def ticker_features(self, model_date, date):
        # need to make this a lot more flexible with number of states
        if model_date < date:
            file_name = "_".join(
                (self.ticker, '3', 'states', 'features', 'date:', date, 'now:', self.compute_date, '.pickle'))
            file_loc = os.path.join(self.symbol_features_path, str(model_date), file_name)
            with open(file_loc, 'rb') as handle:
                ticker_features = pickle.load(handle)
        else:
            print('Loading Feature Date which is in-sample. Change your Model Date')
        return ticker_features

    def ticker_labels_csv(self, date):
        file_loc = os.path.join(self.labels_path, str(date) + '.csv')
        ticker_labels = pd.read_csv(file_loc, index_col=0)
        return ticker_labels

    @staticmethod
    def open_pickle_file(path, pickle_file):
        file_loc = os.path.join(path, pickle_file)
        pickle_to_file = pickle.load(open(file_loc, "rb"))
        return pickle_to_file

    @staticmethod
    def get_date_from_file(file_, numb_):
        return os.path.splitext(file_[numb_])[0]


class MarketFeatures(object):
    # a class to be expanded that uses features for base case -market based only-indicators/features
    """"Requires:
    a dataframe that has TradedPrice And Volume columns
    symbol - A stock symbol on which to form a strategy on.
    short_window - Lookback period for short moving average.
    long_window - Lookback period for long moving average.
    """

    def __init__(self, df):
        #         self.ticker = ticker
        self.df = df

    def load_data(self):
        pass

    def ma_spread(self, short_window=5, long_window=20):
        # function that produces the MA spread, which can be used on its own or as an input for MACD
        short_rolling_px = self.df['TradedPrice'].rolling(window=short_window).mean()
        long_rolling_px = self.df['TradedPrice'].rolling(window=long_window).mean()
        px_name = "_".join(('px_indx', str(short_window), str(long_window)))
        self.df[px_name] = long_rolling_px - short_rolling_px
        return self.df

    def ma_spread_duration(self, short_window=5, long_window=20):
        # function that produces the MA spread, which can be used on its own or as an input for MACD
        short_rolling_px = self.df['Duration'].rolling(window=short_window).mean()
        long_rolling_px = self.df['Duration'].rolling(window=long_window).mean()
        dur_name = "_".join(('dur_indx', str(short_window), str(long_window)))
        self.df[dur_name] = long_rolling_px - short_rolling_px
        return self.df

    def obv_calc(self):
        # on balance volume indicator
        self.df['SignedVolume'] = self.df['Volume'] * np.sign(self.df['TradedPrice'].diff()).cumsum()
        self.df['SignedVolume'].iat[1] = 0
        self.df['OBV'] = self.df['SignedVolume']  # .cumsum()
        self.df = self.df.drop(columns=['SignedVolume'])
        return self.df

    def chaikin_mf(self, period=5):
        # Chaikin money flow indicator
        self.df["MF Multiplier"] = (self.df['TradedPrice'] - (self.df['TradedPrice'].expanding(period).min()) \
                                    - (self.df['TradedPrice'].expanding(period).max() \
                                       - self.df['TradedPrice'])) / (
                                           self.df['TradedPrice'].expanding(period).max() - self.df[ \
                                       'TradedPrice'].expanding(period).min())
        self.df["MF Volume"] = self.df['MF Multiplier'] * self.df['Volume']
        self.df['CMF_' + str(period)] = self.df['MF Volume'].sum() / self.df["Volume"].rolling(period).sum()
        self.df = self.df.drop(columns=['MF Multiplier', 'MF Volume'])
        return self.df

# %%
passport = '/media/ak/My Passport/Data/FinDataReal/'
labelPaths = ['LabelsAlternateOne','LabelsAlternateTwo','LabelsAlternateThree','LabelsAlternateFour','LabelsAlternateFive']
passportData =os.path.join(passport, labelPaths[0])
symbols = os.listdir(passport+'Labels')

idx=1
ticker = symbols[idx]
print(ticker)
filename = "".join((passportData,'/',ticker.split(".")[0],'_AlternateLabels.pickle'))
with open(filename, 'rb') as handle:
    data =pkl.load(handle)

listKeys = list(data.keys())
# Out:
# APF.L

# %%
# [x for b in a for x in b] # Works fine
labelSymbolPaths = [os.path.join(passportData, label, symbol) for label in labelPaths for symbol in symbols]
# double list comprehenstion that creates a directory in the Passport file for each label/symbol
labelSymbolDatePaths =  [os.path.join(labelSymbol, keyDate) for labelSymbol in labelSymbolPaths for keyDate in listKeys]
# takes the label symbol paths and creates a directory indexed by the dates

# %%
location = os.path.join(passport, ticker+'_AlternateLabelsLocations.pkl')
                        
with open(location, 'rb') as handle:
    labelsLocations = pkl.load(handle)

# %%
labelsLocations
# Out:
# defaultdict(dict,
#             {'20170116': {'LabelsAlternateOne': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateOne/APF.L/20170116/20170116.csv',
#               'LabelsAlternateTwo': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateTwo/APF.L/20170116/20170116.csv',
#               'LabelsAlternateThree': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateThree/APF.L/20170116/20170116.csv',
#               'LabelsAlternateFour': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateFour/APF.L/20170116/20170116.csv',
#               'LabelsAlternateFive': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateFive/APF.L/20170116/20170116.csv'},
#              '20170117': {'LabelsAlternateOne': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateOne/APF.L/20170117/20170117.csv',
#               'LabelsAlternateTwo': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateTwo/APF.L/20170117/20170117.csv',
#               'LabelsAlternateThree': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateThree/APF.L/20170117/20170117.csv',
#               'LabelsAlternateFour': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateFour/APF.L/20170117/20170117.csv',
#               'LabelsAlternateFive': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateFive/APF.L/20170117/20170117.csv'},
#              '20170118': {'LabelsAlternateOne': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateOne/APF.L/20170118/20170118.csv',
#               'LabelsAlternateTwo': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateTwo/APF.L/20170118/20170118.csv',
#               'LabelsAlternateThree': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateThree/APF.L/20170118/20170118.csv',
#               'LabelsAlternateFour': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateFour/APF.L/20170118/20170118.csv',
#               'LabelsAlternateFive': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateFive/APF.L/20170118/20170118.csv'},
#              '20170119': {'LabelsAlternateOne': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateOne/APF.L/20170119/20170119.csv',
#               'LabelsAlternateTwo': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateTwo/APF.L/20170119/20170119.csv',
#               'LabelsAlternateThree': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateThree/APF.L/20170119/20170119.csv',
#               'LabelsAlternateFour': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateFour/APF.L/20170119/20170119.csv',
#               'LabelsAlternateFive': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateFive/APF.L/20170119/20170119.csv'},
#              '20170120': {'LabelsAlternateOne': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateOne/APF.L/20170120/20170120.csv',
#               'LabelsAlternateTwo': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateTwo/APF.L/20170120/20170120.csv',
#               'LabelsAlternateThree': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateThree/APF.L/20170120/20170120.csv',
#               'LabelsAlternateFour': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateFour/APF.L/20170120/20170120.csv',
#               'LabelsAlternateFive': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateFive/APF.L/20170120/20170120.csv'},
#              '20170123': {'LabelsAlternateOne': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateOne/APF.L/20170123/20170123.csv',
#               'LabelsAlternateTwo': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateTwo/APF.L/20170123/20170123.csv',
#               'LabelsAlternateThree': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateThree/APF.L/20170123/20170123.csv',
#               'LabelsAlternateFour': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateFour/APF.L/20170123/20170123.csv',
#               'LabelsAlternateFive': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateFive/APF.L/20170123/20170123.csv'},
#              '20170124': {'LabelsAlternateOne': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateOne/APF.L/20170124/20170124.csv',
#               'LabelsAlternateTwo': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateTwo/APF.L/20170124/20170124.csv',
#               'LabelsAlternateThree': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateThree/APF.L/20170124/20170124.csv',
#               'LabelsAlternateFour': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateFour/APF.L/20170124/20170124.csv',
#               'LabelsAlternateFive': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateFive/APF.L/20170124/20170124.csv'},
#              '20170125': {'LabelsAlternateOne': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateOne/APF.L/20170125/20170125.csv',
#               'LabelsAlternateTwo': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateTwo/APF.L/20170125/20170125.csv',
#               'LabelsAlternateThree': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateThree/APF.L/20170125/20170125.csv',
#               'LabelsAlternateFour': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateFour/APF.L/20170125/20170125.csv',
#               'LabelsAlternateFive': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateFive/APF.L/20170125/20170125.csv'},
#              '20170126': {'LabelsAlternateOne': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateOne/APF.L/20170126/20170126.csv',
#               'LabelsAlternateTwo': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateTwo/APF.L/20170126/20170126.csv',
#               'LabelsAlternateThree': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateThree/APF.L/20170126/20170126.csv',
#               'LabelsAlternateFour': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateFour/APF.L/20170126/20170126.csv',
#               'LabelsAlternateFive': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateFive/APF.L/20170126/20170126.csv'},
#              '20170127': {'LabelsAlternateOne': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateOne/APF.L/20170127/20170127.csv',
#               'LabelsAlternateTwo': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateTwo/APF.L/20170127/20170127.csv',
#               'LabelsAlternateThree': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateThree/APF.L/20170127/20170127.csv',
#               'LabelsAlternateFour': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateFour/APF.L/20170127/20170127.csv',
#               'LabelsAlternateFive': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateFive/APF.L/20170127/20170127.csv'},
#              '20170130': {'LabelsAlternateOne': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateOne/APF.L/20170130/20170130.csv',
#               'LabelsAlternateTwo': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateTwo/APF.L/20170130/20170130.csv',
#               'LabelsAlternateThree': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateThree/APF.L/20170130/20170130.csv',
#               'LabelsAlternateFour': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateFour/APF.L/20170130/20170130.csv',
#               'LabelsAlternateFive': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateFive/APF.L/20170130/20170130.csv'},
#              '20170131': {'LabelsAlternateOne': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateOne/APF.L/20170131/20170131.csv',
#               'LabelsAlternateTwo': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateTwo/APF.L/20170131/20170131.csv',
#               'LabelsAlternateThree': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateThree/APF.L/20170131/20170131.csv',
#               'LabelsAlternateFour': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateFour/APF.L/20170131/20170131.csv',
#               'LabelsAlternateFive': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateFive/APF.L/20170131/20170131.csv'},
#              '20170703': {'LabelsAlternateOne': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateOne/APF.L/20170703/20170703.csv',
#               'LabelsAlternateTwo': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateTwo/APF.L/20170703/20170703.csv',
#               'LabelsAlternateThree': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateThree/APF.L/20170703/20170703.csv',
#               'LabelsAlternateFour': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateFour/APF.L/20170703/20170703.csv',
#               'LabelsAlternateFive': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateFive/APF.L/20170703/20170703.csv'},
#              '20170704': {'LabelsAlternateOne': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateOne/APF.L/20170704/20170704.csv',
#               'LabelsAlternateTwo': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateTwo/APF.L/20170704/20170704.csv',
#               'LabelsAlternateThree': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateThree/APF.L/20170704/20170704.csv',
#               'LabelsAlternateFour': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateFour/APF.L/20170704/20170704.csv',
#               'LabelsAlternateFive': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateFive/APF.L/20170704/20170704.csv'},
#              '20170705': {'LabelsAlternateOne': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateOne/APF.L/20170705/20170705.csv',
#               'LabelsAlternateTwo': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateTwo/APF.L/20170705/20170705.csv',
#               'LabelsAlternateThree': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateThree/APF.L/20170705/20170705.csv',
#               'LabelsAlternateFour': '/media/ak/My Passport/Data/FinDataReal/LabelsAlternateFour/APF.L/20