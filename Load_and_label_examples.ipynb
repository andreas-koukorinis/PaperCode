# %%
import numpy as np 
import pandas as pd 
import sys
sys.path.append('/home/ak/Documents/Research/hsmm/')
from IPython.display import Markdown
import datetime as dt 
from hsmm_core.data_utils import get_files_for_ticker, load_data
ticker = 'CCL'
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-2adb8d717f40> in <module>
#       5 from IPython.display import Markdown
#       6 import datetime as dt
# ----> 7 from hsmm_core.data_utils import get_files_for_ticker, load_data
#       8 ticker = 'CCL'
#
# ImportError: cannot import name 'load_data'

# %% [markdown]
# # Downloading data

# %%
Markdown(""" **The function that loads data is still called load_data. The basic arguments 
to this function is the name of the ticker (that corresponds to the sub folder locally on disk)
and optionally dates by which i can filter the loaded data.**
""")
# Out:
#  **The function that loads data is still called load_data. The basic arguments
# to this function is the name of the ticker (that corresponds to the sub folder locally on disk)
# and optionally dates by which i can filter the loaded data.**

# %%
Markdown(""" **Calling it with simply the ticker name will return all dates available for the 
ticker**""")
# Out:
#  **Calling it with simply the ticker name will return all dates available for the
# ticker**

# %%
data1 = load_data(ticker)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-d88b0d283d35> in <module>
# ----> 1 data1 = load_data(ticker)
#
# NameError: name 'load_data' is not defined

# %%
Markdown(""" **If a given date range is required, that can be passed as arguments to the 
loading function. Dates can be passed as datetime objects or strings in format YYYYMMDD**""")
# Out:
#  **If a given date range is required, that can be passed as arguments to the
# loading function. Dates can be passed as datetime objects or strings in format YYYYMMDD**

# %%
start = '20180220' 
end  = '20180418' 
data2 = load_data(ticker, start_date=start, end_date=end)

# %%
Markdown(""" **When labelling data, the labeller has two levels of 
configuration, the first mandatory and the second optional and contigent 
on the selections of the first level. At the first level one needs to 
choose:** 

- **labelling_method**: How do i compare the current row 
to upcoming rows to decide whether it should be labelled as an up move
down move or nothing. One can choose to compare the start and end point 
of an interval / the start point to all points in an interval / the 
start point to an average value in an interval. Moreover at this stage we make a choice of 
whether we want to use absolute level of comparison. This will be apparent by the name 
of the labelling method as it will have one of the suffixes: '_abs'/ '_pct'.  

- **thrshd_method:** How to calculate the % level that 
constitutes an up move (down move). One can choose to use an arbitrary 
level (hard coded) or to calculate an adaptive level based on historical
vol.
""")
# Out:
#  **When labelling data, the labeller has two levels of
# configuration, the first mandatory and the second optional and contigent
# on the selections of the first level. At the first level one needs to
# choose:**
#
# - **labelling_method**: How do i compare the current row
# to upcoming rows to decide whether it should be labelled as an up move
# down move or nothing. One can choose to compare the start and end point
# of an interval / the start point to all points in an interval / the
# start point to an average value in an interval. Moreover at this stage we make a choice of
# whether we want to use absolute level of comparison. This will be apparent by the name
# of the labelling method as it will have one of the suffixes: '_abs'/ '_pct'.
#
# - **thrshd_method:** How to calculate the % level that
# constitutes an up move (down move). One can choose to use an arbitrary
# level (hard coded) or to calculate an adaptive level based on historical
# vol.

# %%
Markdown(""" **If one chooses to threshold up/down moves by some method 
that depends on historical vol, a second level of configuration 
is required that will set the following variables:**

- **thrshd_vol_window:** How many days to use too calculate the a
average used for historical vol. 

- **updown_thrshd_vol_pct:** What perecent of the historical vol consitutes 
an up move/down move""")
# Out:
#  **If one chooses to threshold up/down moves by some method
# that depends on historical vol, a second level of configuration
# is required that will set the following variables:**
#
# - **thrshd_vol_window:** How many days to use too calculate the a
# average used for historical vol.
#
# - **updown_thrshd_vol_pct:** What perecent of the historical vol consitutes
# an up move/down move

# %%
Markdown(""" **Let us create an working example. We 'd like to 
label points as:** 

- Compare the start and end point of an interval including 10 trades
 **<-- labelling window is 10 and our labelling method is simple_ep.** 

-Set the absolute level of up or down move as the 10% of averaged historical vol of 
last 5 days (simple average) **<-- thrshd_method is historical_vol_ma, updown_thrshd_vol_pct 
is 10, thrshd_vol_window is 5.**
""")
# Out:
#  **Let us create an working example. We 'd like to
# label points as:**
#
# - Compare the start and end point of an interval including 10 trades
#  **<-- labelling window is 10 and our labelling method is simple_ep.**
#
# -Set the absolute level of up or down move as the 10% of averaged historical vol of
# last 5 days (simple average) **<-- thrshd_method is historical_vol_ma, updown_thrshd_vol_pct
# is 10, thrshd_vol_window is 5.**

# %%
from hsmm_core.consts import LabellingChoice, ThresholdMethod 
from hsmm_core.labelling import DataLabellingSimple 


labeller = DataLabellingSimple(
                    # Style of labelling method - Here we compare rolling 
                    # inervals end points in absolute terms 
                    labelling_method=LabellingChoice.simple_ep_abs, 
                    # Window for labelling method= Number of look ahead trades that control up /down move
                    rolling_window=5,
                    # Calculate threshold by means of moving average historical vol
                    thrshd_method=ThresholdMethod.historical_vol_ma,
                    # Use the last 5 days for the above average. 
                    thrshd_vol_window=5,
                    # Pct of historical vol to use for threshold, i.e. 0.1 * historical vol
                    updown_thrshd_vol_pct=10.)

# %%
labeller.label_training_data(data2)

# %%
Markdown(""" **Here is another example, where we dont use the historical vol at all. Instead 
we set an arbitrary level as a pct of price change (notice how this is reflected to 
the name of hte labelling method). We still just compare the end points of 
a rolling interval. Here we use 1 %**""")
# Out:
#  **Here is another example, where we dont use the historical vol at all. Instead
# we set an arbitrary level as a pct of price change (notice how this is reflected to
# the name of hte labelling method). We still just compare the end points of
# a rolling interval. Here we use 1 %**

# %%
labeller = DataLabellingSimple(
                    # Style of labelling method - Here we compare rolling 
                    # inervals end points in absolute terms 
                    labelling_method=LabellingChoice.simple_ep_abs, 
                    # Window for labelling method= Number of look ahead trades that control up /down move
                    rolling_window=5,
                    # Calculate threshold by means of moving average historical vol
                    thrshd_method=ThresholdMethod.arbitrary,
                    # Use the last 5 days for the above average. 
                    updown_thrshd_pct=1.)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-05abcda11206> in <module>()
#       8                     thrshd_method=ThresholdMethod.arbitrary,
#       9                     # Use the last 5 days for the above average.
# ---> 10                     updown_thrshd_pct=1.)
#
# TypeError: __init__() got an unexpected keyword argument 'updown_thrshd_pct'

# %%
labeller.label_training_data(data2)

# %%
df = data2.values()[1] 
df['label_simple_ep_abs__window_5__thres_arbitrary__pct_1.0']
# Out:
#       Unnamed: 0      Date[G]       TradedTime  TradedPrice    Volume  \
# 377       248256  06-APR-2018  08:00:32.053281       4636.0      94.0
# 378       248258  06-APR-2018  08:00:32.053292       4636.0       6.0
# 379       248260  06-APR-2018  08:00:32.053292       4636.0      94.0
# 380       248262  06-APR-2018  08:00:32.053292       4636.0      74.0
# 381       248264  06-APR-2018  08:00:32.053292       4636.0      48.0
# 382       248283  06-APR-2018  08:00:46.392113       4637.0      95.0
# 383       248285  06-APR-2018  08:00:46.392125       4637.0      11.0
# 384       248287  06-APR-2018  08:00:46.403565       4637.0      50.0
# 385       248296  06-APR-2018  08:00:46.403650       4637.0      50.0
# 386       248321  06-APR-2018  08:01:02.315107       4638.0      73.0
# 387       248323  06-APR-2018  08:01:02.315120       4638.0      27.0
# 388       248325  06-APR-2018  08:01:02.315120       4638.0      97.0
# 389       248327  06-APR-2018  08:01:02.315120       4638.0     158.0
# 390       248329  06-APR-2018  08:01:02.315120       4638.0      50.0
# 391       248419  06-APR-2018  08:01:18.977776       4639.0      50.0
# 392       248421  06-APR-2018  08:01:18.977776       4639.0     119.0
# 393       248423  06-APR-2018  08:01:18.977776       4639.0      59.0
# 394       248454  06-APR-2018  08:01:19.169427       4639.0      90.0
# 395       248456  06-APR-2018  08:01:19.169427       4639.0     120.0
# 396       248458  06-APR-2018  08:01:19.169427       4639.0       9.0
# 397       248463  06-APR-2018  08:01:19.169427       4640.0      16.0
# 398       248479  06-APR-2018  08:01:23.519826       4639.0      91.0
# 399       248481  06-APR-2018  08:01:23.519863       4639.0      90.0
# 400       248483  06-APR-2018  08:01:23.519863       4639.0      99.0
# 401       248529  06-APR-2018  08:01:37.460243       4639.0      80.0
# 402       248531  06-APR-2018  08:01:37.460243       4639.0     121.0
# 403       248533  06-APR-2018  08:01:37.460243       4639.0     180.0
# 404       248535  06-APR-2018  08:01:37.460243       4639.0      80.0
# 405       248537  06-APR-2018  08:01:37.460255       4639.0      41.0
# 406       248572  06-APR-2018  08:01:49.686768       4639.0      90.0
# ...          ...          ...              ...          ...       ...
# 4289      321495  06-APR-2018  15:28:50.440749       4610.0     100.0
# 4290      321499  06-APR-2018  15:28:50.440761       4609.0      38.0
# 4291      321501  06-APR-2018  15:28:50.440761       4609.0     150.0
# 4292      321503  06-APR-2018  15:28:50.450456       4609.0      12.0
# 4293      321558  06-APR-2018  15:29:09.960250       4610.0     191.0
# 4294      321611  06-APR-2018  15:29:11.330097       4610.0     176.0
# 4295      321613  06-APR-2018  15:29:11.339316       4610.0     150.0
# 4296      321615  06-APR-2018  15:29:11.339316       4610.0      33.0
# 4297      321634  06-APR-2018  15:29:14.350433       4610.0     104.0
# 4298      321636  06-APR-2018  15:29:14.350433       4610.0     191.0
# 4299      321641  06-APR-2018  15:29:14.350813       4610.0     415.0
# 4300      321643  06-APR-2018  15:29:14.350813       4610.0     258.0
# 4301      321645  06-APR-2018  15:29:14.350825       4610.0     147.0
# 4302      321647  06-APR-2018  15:29:14.350825       4610.0     120.0
# 4303      321665  06-APR-2018  15:29:14.720325       4611.0     166.0
# 4304      321667  06-APR-2018  15:29:14.720325       4611.0     110.0
# 4305      321669  06-APR-2018  15:29:14.720337       4611.0     124.0
# 4306      321672  06-APR-2018  15:29:14.730050       4611.0      26.0
# 4307      321687  06-APR-2018  15:29:14.819811       4610.0      42.0
# 4308      321689  06-APR-2018  15:29:14.819811       4610.0      50.0
# 4309      321713  06-APR-2018  15:29:18.560032       4609.0       1.0
# 4310      321723  06-APR-2018  15:29:23.770266       4609.0      76.0
# 4311      321724  06-APR-2018  15:29:23.770722       4609.0      61.0
# 4312      321744  06-APR-2018  15:29:48.198627       4608.0      84.0
# 4313      321748  06-APR-2018  15:29:48.484525       4608.0      14.0
# 4314      321750  06-APR-2018  15:29:48.484525       4608.0      52.0
# 4315      321764  06-APR-2018  15:29:53.220719       4608.0      81.0
# 4316      322362  06-APR-2018  15:35:05.738634       4624.0  118518.0
# 4317      322377  06-APR-2018  15:37:50.320844       4624.0    4209.0
# 4318      322379  06-APR-2018  15:37:50.320844       4624.0    1791.0
#
#       Duration  ReturnTradedPrice ticker  \
# 377      122.0           0.000000    CCL
# 378        0.0           0.000000    CCL
# 379        0.0           0.000000    CCL
# 380        0.0           0.000000    CCL
# 381        0.0           0.000000    CCL
# 382       14.0           0.000216    CCL
# 383        0.0           0.000000    CCL
# 384        0.0           0.000000    CCL
# 385        0.0           0.000000    CCL
# 386       16.0           0.000216    CCL
# 387        0.0           0.000000    CCL
# 388        0.0           0.000000    CCL
# 389        0.0           0.000000    CCL
# 390        0.0           0.000000    CCL
# 391       16.0           0.000216    CCL
# 392        0.0           0.000000    CCL
# 393        0.0           0.000000    CCL
# 394        1.0           0.000000    CCL
# 395        0.0           0.000000    CCL
# 396        0.0           0.000000    CCL
# 397        0.0           0.000216    CCL
# 398        4.0          -0.000216    CCL
# 399        0.0           0.000000    CCL
# 400        0.0           0.000000    CCL
# 401       14.0           0.000000    CCL
# 402        0.0           0.000000    CCL
# 403        0.0           0.000000    CCL
# 404        0.0           0.000000    CCL
# 405        0.0           0.000000    CCL
# 406       12.0           0.000000    CCL
# ...        ...                ...    ...
# 4289       3.0           0.000217    CCL
# 4290       0.0          -0.000217    CCL
# 4291       0.0           0.000000    CCL
# 4292       0.0           0.000000    CCL
# 4293      19.0           0.000217    CCL
# 4294       2.0           0.000000    CCL
# 4295       0.0           0.000000    CCL
# 4296       0.0           0.000000    CCL
# 4297       3.0           0.000000    CCL
# 4298       0.0           0.000000    CCL
# 4299       0.0           0.000000    CCL
# 4300       0.0           0.000000    CCL
# 4301       0.0           0.000000    CCL
# 4302       0.0           0.000000    CCL
# 4303       0.0           0.000217    CCL
# 4304       0.0           0.000000    CCL
# 4305       0.0           0.000000    CCL
# 4306       0.0           0.000000    CCL
# 4307       0.0          -0.000217    CCL
# 4308       0.0           0.000000    CCL
# 4309       4.0          -0.000217    CCL
# 4310       5.0           0.000000    CCL
# 4311       0.0           0.000000    CCL
# 4312      25.0          -0.000217    CCL
# 4313       0.0           0.000000    CCL
# 4314       0.0           0.000000    CCL
# 4315       5.0           0.000000    CCL
# 4316     312.0           0.003472    CCL
# 4317     165.0           0.000000    CCL
# 4318       0.0           0.000000    CCL
#
#       label_simple_ep_abs__window_5__thres_historical_vol_ma__vol_pct_10.0  \
# 377                                                -1.0
# 378                                                 1.0
# 379                                                 1.0
# 380                                                 1.0
# 381                                                 1.0
# 382                                                 1.0
# 383                                                 1.0
# 384                                                 1.0
# 385                                                 1.0
# 386                                                -1.0
# 387                                                 1.0
# 388                                                 1.0
# 389                                                 1.0
# 390                                                 1.0
# 391                                                -1.0
# 392                                                -1.0
# 393                                                 1.0
# 394                                                -1.0
# 395                                                -1.0
# 396                                                -1.0
# 397                                                -1.0
# 398                                                -1.0
# 399                                                -1.0
# 400                                                -1.0
# 401                                                -1.0
# 402                                                -1.0
# 403                                                 1.0
# 404                                                 1.0
# 405                                                 1.0
# 406                                                 1.0
# ...                                                 ...
# 4289                                               -1.0
# 4290                                                1.0
# 4291                                                1.0
# 4292                                                1.0
# 4293                                               -1.0
# 4294                                               -1.0
# 4295                                               -1.0
# 4296                                               -1.0
# 4297                                               -1.0
# 4298                                               -1.0
# 4299                                                1.0
# 4300                                                1.0
# 4301                                                1.0
# 4302                                                1.0
# 4303                                               -1.0
# 4304                                               -1.0
# 4305                                               -1.0
# 4306                                               -1.0
# 4307                                               -1.0
# 4308                                               -1.0
# 4309                                               -1.0
# 4310                                               -1.0
# 4311                                               -1.0
# 4312                                                1.0
# 4313                                                1.0
# 4314                                                1.0
# 4315                                                NaN
# 4316                                                NaN
# 4317                                                NaN
# 4318                                                NaN
#
#       label_simple_ep_abs__window_5__thres_arbitrary__pct_1.0
# 377                                                -1.0
# 378                                                 1.0
# 379                                                 1.0
# 380                                                 1.0
# 381                                                 1.0
# 382                                                 1.0
# 383                                                 1.0
# 384                                                 1.0
# 385                                                 1.0
# 386                                                -1.0
# 387                                                 1.0
# 388                                                 1.0
# 389                                                 1.0
# 390                                                 1.0
# 391                                                -1.0
# 392                                                -1.0
# 393                                                 1.0
# 394                                                -1.0
# 395                                                -1.0
# 396                                                -1.0
# 397                                                -1.0
# 398                                                -1.0
# 399                                                -1.0
# 400                                                -1.0
# 401                                                -1.0
# 402                                                -1.0
# 403                                                 1.0
# 404                                                 1.0
# 405                                                 1.0
# 406                                                 1.0
# ...                                                 ...
# 4289                                               -1.0
# 4290                                                1.0
# 4291                                                1.0
# 4292                                                1.0
# 4293                                               -1.0
# 4294                                               -1.0
# 4295                                               -1.0
# 4296                                               -1.0
# 4297                                               -1.0
# 4298                                               -1.0
# 4299                                                1.0
# 4300                                                1.0
# 4301                                                1.0
# 4302                                                1.0
# 4303                                               -1.0
# 4304                                               -1.0
# 4305                                               -1.0
# 4306                                               -1.0
# 4307                                               -1.0
# 4308                                               -1.0
# 4309                                               -1.0
# 4310                                               -1.0
# 4311                                               -1.0
# 4312                                                1.0
# 4313                                                1.0
# 4314                                                1.0
# 4315                                                NaN
# 4316                                                NaN
# 4317                                                NaN
# 4318                                                NaN
#
# [3942 rows x 10 columns]
